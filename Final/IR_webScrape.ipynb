# %% [markdown]
# # 爬蟲檔案
# * 參考連結
#   * [爬社團 - selenium](https://blog.happycoding.today/pythonbeginner-ep7/)
#   * [自動登入](https://ithelp.ithome.com.tw/articles/10242625)

# %% [markdown]
# # pip install

# %%
pip install html5lib
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import

# %%
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import time
import csv
from selenium.webdriver.chrome.service import Service as ChromeService

# %% [markdown]
# # Open Website and Auto Login

# %%
# 打開 吃貨台大
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)
driver=webdriver.Chrome("./chromedriver",chrome_options=chrome_options)
driver.get("https://www.facebook.com/ntueater/")
# Out:
# /var/folders/7p/hltnmr495jx_bg1645lk4y2c0000gn/T/ipykernel_17419/226782128.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("./chromedriver",chrome_options=chrome_options)
# /var/folders/7p/hltnmr495jx_bg1645lk4y2c0000gn/T/ipykernel_17419/226782128.py:5: DeprecationWarning: use options instead of chrome_options
#   driver=webdriver.Chrome("./chromedriver",chrome_options=chrome_options)

# %%
from bs4 import BeautifulSoup

htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'html5lib')


title = soup.find_all('div',{'dir' :'auto'})
print(len(title))
print(title[:10])
# Out:
# 761
# ...

# %%
for i in title:
    tmp = i.find_all('span')
    print(tmp)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
# # 各航空的 url

# import requests
# from bs4 import BeautifulSoup
# import re
# import pandas as pd
# from datetime import datetime

# url = 'https://www.facebook.com/ntueater/'

# response = requests.get(url)

# soup = BeautifulSoup(response.text, "html.parser")

# print(soup)
# review_url_list =[]

# # tab content
# tabs = soup.findAll('div',{'class' :'x1cy8zhl x78zum5 x1q0g3np xod5an3 x1pi30zi x1swvt13 xz9dl7a'})
# # tab = tabs.findAll('div', {'class' : 'auto'})
# print(tabs)

# # if len(tab)>0:    
# #     for idx, one in enumerate(tab):    
# #         print('tab No.', idx+1)
# #         for a in one.find_all('a', href=True):
# #             review_url_list.append(tmp)

# %%
post=[]
soup=BeautifulSoup(driver.page_source,"lxml")
first=soup.find_all(class_="auto")
print(first)
# for i in first:
#     post.append(i.text)

# timme=soup.find_all("abbr")
# real=[]
# for i in timme:
#     if i.get("title")!=None:
#         real.append(i.get("title"))

# while real[-1].split(" ")[0]!="2019/9/3":
#     driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
#     post=[]
#     soup=BeautifulSoup(driver.page_source,"lxml")
#     first=soup.find_all(class_="text_exposed_root")
#     for i in first:
#         post.append(i.text)

#     timme=soup.find_all("abbr")
#     real=[]
#     for i in timme:
#         if i.get("title")!=None:
#             real.append(i.get("title"))
#     print(real[-1].split(" ")[0])


# print(len(post))

driver.close()
